# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create an array that contains the number of users each language has
Average_Value = [108735, 118835, 156839, 249624, 316620]
x_axis = np.arange(len(Average_Value))

# %%
# Tell matplotlib that we will be making a bar chart
# Users is our y axis and x_axis is, of course, our x axis
# We apply align="edge" to ensure our bars line up with our tick marks
plt.bar(x_axis, Average_Value, color='r', alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["1", "2", "3", "4", "5"])
# Out:
# ([<matplotlib.axis.XTick at 0x120ec2240>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
# Sets the x limits of the current chart
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Sets the y limits of the current chart
plt.ylim(0, max(Average_Value)+5000)
# Out:
# (0, 321620)

# %%
# Give our chart some labels and a tile
plt.title("Average Housing Value by Number of Bedrooms Cuyahoga County Suburbs")
plt.xlabel("Number of Bedrooms")
plt.ylabel("Total Value - Mesaured using myplace.cuyahogacounty.us")
# Out:
# Text(22.944444444444432, 0.5, 'Total Value - Mesaured using myplace.cuyahogacounty.us')
